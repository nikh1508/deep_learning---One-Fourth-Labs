# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
x = np.random.random((1, 10))
y = np.power(x, 0.33)

# %%
print(y)
# Out:
# [[0.91955166 0.7199718  0.95558049 0.64179786 0.26109951 0.76041084
#   0.91718423 0.96502426 0.70744277 0.56787169]]

# %%
sns.set()

# %%
sns.lineplot(x[0], y[0])
